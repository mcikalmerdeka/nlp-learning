# %%
# Install uv package manager
# !pip install uv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 80.7 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !uv pip install langchain_docling docling langchain_openai langchain_qdrant langchain_text_splitters
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 140 packages in 1.31s
# Prepared 35 packages in 1.46s
# Uninstalled 3 packages in 483ms
# Installed 35 packages in 110ms
#  + colorlog==6.10.1
#  + docling==2.73.1
#  + docling-core==2.65.1
#  + docling-ibm-models==3.11.0
#  + docling-parse==4.7.3
#  + faker==40.4.0
#  + filetype==1.2.0
#  - huggingface-hub==1.4.0
#  + huggingface-hub==0.36.2
#  + jsonlines==4.0.0
#  + jsonref==1.1.0
#  - langchain-core==1.2.9
#  + langchain-core==1.2.13
#  + langchain-docling==2.0.0
#  + langchain-openai==1.1.9
#  + langchain-qdrant==1.1.0
#  + langchain-text-splitters==1.1.0
#  + latex2mathml==3.78.1
#  + marko==2.2.2
#  + mpire==2.10.2
#  + polyfactory==3.2.0
#  + portalocker==3.2.0
#  + pyclipper==1.4.0
#  + pylatexenc==2.10
#  + pypdfium2==5.4.0
#  + python-docx==1.2.0
#  + python-pptx==1.0.2
#  + qdrant-client==1.16.2
#  + rapidocr==3.6.0
#  + semchunk==2.2.2
#  - transformers==5.0.0
#  + transformers==4.57.6
#  + tree-sitter==0.25.2
# ...

# %% [markdown]
# # Document Ingestion

# %%
# Check current directory in colab
import os
print(os.getcwd())  # Shows: /content
# Out:
# /content

# %%
# Load file from GitHub - need to use raw URL

## PDF with tables example
source_pdf = "https://raw.githubusercontent.com/mcikalmerdeka/nlp-learning/main/docling-experimentation/data/pdfs/pdf_with_tables_example.pdf"  # Use raw GitHub URL
source_pdf_2 = "https://raw.githubusercontent.com/mcikalmerdeka/nlp-learning/main/docling-experimentation/data/pdfs/long_table_pdf.pdf"

## Images example
source_image_1 = "https://raw.githubusercontent.com/mcikalmerdeka/nlp-learning/main/docling-experimentation/data/images/page_2.png"  
source_image_2 = "https://raw.githubusercontent.com/mcikalmerdeka/nlp-learning/main/docling-experimentation/data/images/page_6.png"  
source_image_3 = "https://raw.githubusercontent.com/mcikalmerdeka/nlp-learning/main/docling-experimentation/data/images/page_9.png"  

source_image_4 = "https://raw.githubusercontent.com/mcikalmerdeka/nlp-learning/main/docling-experimentation/data/images/sample_image_1.png"
source_image_5 = "https://raw.githubusercontent.com/mcikalmerdeka/nlp-learning/main/docling-experimentation/data/images/sample_image_2.png"
source_image_6 = "https://raw.githubusercontent.com/mcikalmerdeka/nlp-learning/main/docling-experimentation/data/images/sample_image_3.png"
source_image_7 = "https://raw.githubusercontent.com/mcikalmerdeka/nlp-learning/main/docling-experimentation/data/images/sample_image_4.png"

source_image_8 = "https://raw.githubusercontent.com/mcikalmerdeka/nlp-learning/main/docling-experimentation/data/images/long_table_image.jpg"

## Excel example
source_excel = "https://raw.githubusercontent.com/mcikalmerdeka/nlp-learning/main/docling-experimentation/data/spreadsheets/example_table.xlsx"  

## Powerpoint example
source_powerpoint = "https://raw.githubusercontent.com/mcikalmerdeka/nlp-learning/main/docling-experimentation/data/powerpoints/sustainable_urban_mobility_trends_2025.pptx"

# # For URLs, don't use open() - let DocumentConverter handle it
# # Or if you want to download it first:
# import requests
# response = requests.get(source)
# pdf_content = response.content

# # Print the PDF content
# print(pdf_content)

# %%
from docling.document_converter import DocumentConverter

# Initialize the DocumentConverter
converter = DocumentConverter()

# %% [markdown]
# ## Custom Conversion Settings

# %%
# Custor conversion (details: https://docling-project.github.io/docling/examples/custom_convert/)
## Only the ones that I think important is listed here

# from docling.datamodel.accelerator_options import AcceleratorDevice, AcceleratorOptions
# from docling.datamodel.base_models import InputFormat
# from docling.datamodel.pipeline_options import (
#     PdfPipelineOptions,
#     TableStructureOptions,
# )
# from docling.document_converter import DocumentConverter, PdfFormatOption

# 1. Docling Parse with EasyOCR (default)
# -------------------------------
# Enables OCR and table structure with EasyOCR, using automatic device
# selection via AcceleratorOptions. Adjust languages as needed.
# pipeline_options = PdfPipelineOptions()
# pipeline_options.do_ocr = True
# pipeline_options.do_table_structure = True
# pipeline_options.table_structure_options = TableStructureOptions(
#     do_cell_matching=True
# )
# pipeline_options.ocr_options.lang = ["es"]
# pipeline_options.accelerator_options = AcceleratorOptions(
#     num_threads=4, device=AcceleratorDevice.AUTO
# )

# doc_converter = DocumentConverter(
#     format_options={
#         InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options) # Change this based on the document input format
#     }
# )

# 2. Docling Parse with EasyOCR (CPU only)
# -------------------------------------
# pipeline_options = PdfPipelineOptions()
# pipeline_options.do_ocr = True
# pipeline_options.ocr_options.use_gpu = False  # <-- set this.
# pipeline_options.do_table_structure = True
# pipeline_options.table_structure_options = TableStructureOptions(do_cell_matching=True)

# doc_converter = DocumentConverter(
#     format_options={
#         InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
#     }
# )

# 3. Docling Parse with Tesseract
# ----------------------------
# pipeline_options = PdfPipelineOptions()
# pipeline_options.do_ocr = True
# pipeline_options.do_table_structure = True
# pipeline_options.table_structure_options = TableStructureOptions(do_cell_matching=True)
# pipeline_options.ocr_options = TesseractOcrOptions()

# doc_converter = DocumentConverter(
#     format_options={
#         InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
#     }
# )

# %% [markdown]
# ## Check PDF Example

# %%
# Check pdf example
doc = converter.convert(source_pdf).document
print(doc.export_to_markdown())
# Out:
# WARNING:docling.models.factories.base_factory:The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# WARNING:docling.models.factories.base_factory:The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# [INFO] 2026-01-22 04:12:08,838 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-22 04:12:08,848 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-22 04:12:08,852 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.5.0/torch/PP-OCRv4/det/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-22 04:12:10,176 [RapidOCR] download_file.py:82: Download size: 13.83MB
# [INFO] 2026-01-22 04:12:10,401 [RapidOCR] download_file.py:95: Successfully saved to: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# ...

# %%
# Check pdf with long table example
doc = converter.convert(source_pdf_2).document
print(doc.export_to_markdown())
# Out:
# WARNING:docling.models.factories.base_factory:The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# WARNING:docling.models.factories.base_factory:The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# [INFO] 2026-02-17 11:08:32,027 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-02-17 11:08:32,036 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-02-17 11:08:32,039 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.6.0/torch/PP-OCRv4/det/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-02-17 11:08:32,811 [RapidOCR] download_file.py:82: Download size: 13.83MB
# [INFO] 2026-02-17 11:08:32,963 [RapidOCR] download_file.py:95: Successfully saved to: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# ...

# %% [markdown]
# ## Check Image Example

# %%
from pprint import pprint
doc = converter.convert(source_image_1).document

# %%
pprint(doc.export_to_dict())
# Out:
# {'body': {'children': [{'$ref': '#/texts/0'}, {'$ref': '#/tables/0'}],
#           'content_layer': 'body',
#           'label': 'unspecified',
#           'name': '_root_',
#           'self_ref': '#/body'},
#  'form_items': [],
#  'furniture': {'children': [],
#                'content_layer': 'furniture',
#                'label': 'unspecified',
#                'name': '_root_',
#                'self_ref': '#/furniture'},
#  'groups': [],
#  'key_value_items': [],
#  'name': 'page_2',
#  'origin': {'binary_hash': 2977352306312714560,
#             'filename': 'page_2.png',
#             'mimetype': 'application/pdf'},
#  'pages': {'1': {'page_no': 1, 'size': {'height': 1169.0, 'width': 1654.0}}},
#  'pictures': [],
#  'schema_name': 'DoclingDocument',
#  'tables': [{'annotations': [],
#              'captions': [],
#              'children': [],
#              'content_layer': 'body',
#              'data': {'grid': [[{'bbox': {'b': 161.89985148111978,
# ...

# %%
print(doc.export_to_text())
# Out:
# WARNING:docling_core.types.doc.document:Parameter `strict_text` has been deprecated and will be ignored.
# ## 目次~戾
#
# | 車丙情報BMC情報                                       | FR//<RF(UPR) +FR CB(UPR)   | FR//<RF(UPR) +FR CB(UPR)   |
# |-------------------------------------------------------|----------------------------|----------------------------|
# |                                                       | 部品点数                   |                            |
# | Brand                                                 | Quantity ofParts           | Total Weight(kg)           |
# | Cadillac Lyriq Debut Edition 2023                     | 1                          | 6.84                       |
# | Smart #1Premium 2023                                  | 5                          | 13.34                      |
# | Volkswagen Golf VIII1.5 eTSi Style 1st Edition II2020 | 1                          | 7.98                       |
# ...

# %%
pprint(doc.export_to_doctags())
# Out:
# ('<doctag><section_header_level_1><loc_7><loc_32><loc_32><loc_42>目次~戾</section_header_level_1>\n'
#  '<otsl><loc_7><loc_48><loc_293><loc_350><ched>車丙情報BMC情報<ched>FR//<RF(UPR) +FR '
#  'CB(UPR)<lcel><nl><ecel><ched>部品点数<ecel><nl><fcel>Brand<ched>Quantity '
#  'ofParts<ched>Total Weight(kg)<nl><fcel>Cadillac Lyriq Debut Edition '
#  '2023<fcel>1<fcel>6.84<nl><fcel>Smart #1Premium '
#  '2023<fcel>5<fcel>13.34<nl><fcel>Volkswagen Golf VIII1.5 eTSi Style 1st '
#  'Edition II2020<fcel>1<fcel>7.98<nl><fcel>Volkswagen Polo 1.0 TSi Highline '
#  '2018<fcel>1<fcel>7.99<nl><fcel>VolkswagenTiguan 2.0 TDi 4Motion Highline '
#  '2016<fcel>1<fcel>9.56<nl><fcel>Volkswagen Passat Variant 2.0 TDi SCR '
#  'Highline 2015<fcel>1<fcel>7.65<nl><fcel>Volkswagen Golf VIl1.4 TSi '
#  'Comfortline 2013<fcel>1<fcel>8.68<nl><fcel>Volkswagen Up!1.0 Take Up! '
#  '2012<fcel>1<fcel>6.13<nl><fcel>Volkswagen Touran 2.0 TDi Highline '
#  '2011<fcel>1<fcel>7.41<nl><fcel>Audi Q4 e-tron 50 quattro '
# ...

# %%
print(doc.export_to_html())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8"/>
# <title>page_2</title>
# <meta name="generator" content="Docling HTML Serializer"/>
# <style>
#     html {
#         background-color: #f5f5f5;
#         font-family: Arial, sans-serif;
#         line-height: 1.6;
#     }
#     body {
#         max-width: 800px;
#         margin: 0 auto;
#         padding: 2rem;
#         background-color: white;
#         box-shadow: 0 0 10px rgba(0,0,0,0.1);
#     }
#     h1, h2, h3, h4, h5, h6 {
#         color: #333;
#         margin-top: 1.5em;
#         margin-bottom: 0.5em;
#     }
#     h1 {
#         font-size: 2em;
#         border-bottom: 1px solid #eee;
#         padding-bottom: 0.3em;
#     }
#     table {
#         border-collapse: collapse;
#         margin: 1em 0;
#         width: 100%;
#     }
#     th, td {
#         border: 1px solid #ddd;
#         padding: 8px;
#         text-align: left;
#     }
#     th {
#         background-color: #f2f2f2;
# ...

# %%
# Check image 1 example
doc = converter.convert(source_image_1).document
print(doc.export_to_markdown())
# Out:
# WARNING:docling.models.factories.base_factory:The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# WARNING:docling.models.factories.base_factory:The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# [INFO] 2026-01-22 05:42:59,697 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-22 05:42:59,705 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-22 05:42:59,708 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.5.0/torch/PP-OCRv4/det/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-22 05:43:00,819 [RapidOCR] download_file.py:82: Download size: 13.83MB
# [INFO] 2026-01-22 05:43:01,401 [RapidOCR] download_file.py:95: Successfully saved to: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# ...

# %%
# Check image 2 example
doc = converter.convert(source_image_2).document
print(doc.export_to_markdown())
# Out:
# ## 080×要素構造讨質量部品点数未幼
#
# 强度对策$国)部品
#
# <!-- image -->
#
# 注)質量080N面值502N,要素構造CAE導出
#
# <!-- image -->
#
# | 部品点数 台当 )   | 080N比   | 080N比   | 502N比   |        | - 350   |
# |-------------------|----------|----------|----------|--------|---------|
# |                   | +4       | +5       | +1       |        |         |
# | 合計質量增减台当) | 080N比   | 080N比   | 502N比   | 080N比 | 502N比  |
# | 合計質量增减台当) | 922      | 1880     | 958      | 1150   | 228     |
#
# 新設部品

# %%
# Check image 3 example
doc = converter.convert(source_image_3).document
print(doc.export_to_markdown())
# Out:
# ## 板厚感度
#
# 車轴間剛性 (GJ值)
#
# ## 右表
#
# 周剛性劾果的部品
#
# ①64112 R/F
#
# Fr
#
# - ②64213 の字
#
# - ③64217 壁
#
# - ④64111 礼
#
# - ?61633 W/H
#
# - ?61731 R/S
#
# - ①61711 R/S 7 R/F
#
# ## の順
#
# |                                | PSHELL 品名        |     |   板厚G/W |
# |--------------------------------|--------------------|-----|-----------|
# |                                | 537270Fr77         | 1.8 |  1.18e+10 |
# |                                | 616770W/H血        | 21  |  3.74e+09 |
# | １234                          | 616710WH7夕        | 2.3 |  3.62e+09 |
# |                                | 616711WH7夕        | 2.3 |  1.78e+09 |
# | 5                              | 641120八R/F前      | 0.6 |  1.15e+09 |
# | 6                              | 611210             |     |  9.77e+08 |
# | 7                              | 642130-の字        | 1.2 |  8.99e+08 |
# |                                | 611490Fr1R/F       | 1.2 |  7.8e+08  |
# ...

# %%
# Check image 4 example
doc = converter.convert(source_image_4).document
print(doc.export_to_markdown())
print("="*100)

# Check image 5 example
doc = converter.convert(source_image_5).document
print(doc.export_to_markdown())
print("="*100)

# Check image 6 example
doc = converter.convert(source_image_6).document
print(doc.export_to_markdown())
print("="*100)

# Check image 7 example
doc = converter.convert(source_image_7).document
print(doc.export_to_markdown())
print("="*100)
# Out:
# WARNING:docling.models.factories.base_factory:The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# WARNING:docling.models.factories.base_factory:The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# [INFO] 2026-01-26 08:48:18,508 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-26 08:48:18,520 [RapidOCR] device_config.py:57: Using GPU device with ID: 0
# [INFO] 2026-01-26 08:48:18,524 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.5.0/torch/PP-OCRv4/det/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-26 08:48:19,889 [RapidOCR] download_file.py:82: Download size: 13.83MB
# [INFO] 2026-01-26 08:48:20,041 [RapidOCR] download_file.py:95: Successfully saved to: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# ...

# %%
# Check image 8 example
doc = converter.convert(source_image_8).document
print(doc.export_to_markdown())
# Out:
# | 12.45 - 13.00  ！  12.45 - 13.00  62  1  5  7  4  13.00 - 13.15  95  29  3  5  2  2  1  13.00 - 13.15  81  15  8  1  2  3  1  13.15 - 13.30  112  25  3  2  4  13.15 - 13.30  102  1  32  1  3  4  13.30 - 13.45  148  40  2  10  3  1  13.30 - 13.45  97  1  8  4  7  13.415 - 14.00  195  51  5  2  5  5  2  13.45 - 14.00  81  5  20  3  14.00 - 14.15  222  31  8  3  2  1  5  14.00 - 14.15  77  4  2  2  3  10  14.15 - 14.30  133  48  5  9  2  4  14.15 - 14.30  62  4  3  8  14.30 - 14.45  231  0  8  9  1  2  16  1  5  4  14.30 - 14.45  99  2  32  6  1  6  10  14.45 - 15.00  99  36  1  10  3  5  7  1  5  1  14.45 - 15.00  25  2  4  15.00 - 15.15  70  26  3  2  3  2  6  1  15.00 - 15.15  40  2  7  3  15.15 - 15.30  68  28  1  1  2  3  2  1  15.15 - 15.30  54  5  7  1  5  2  15.30 - 15.45  114  24  2  3  9  15.30 - 15.45  31  8  3  2  1  5  9  15.45 - 16.00  103  37  3  4  1  2  11  8  15.45 - 16.00  69  2  27  4  9  3  1  16.00 - 16.15  78  31  1  5  3  5  2  11  1  16.00 - 16.15  8  4  29  2 
# ...

# %% [markdown]
# ## Check Spreadsheet Example

# %%
# Check excel example
doc = converter.convert(source_excel).document
print(doc.export_to_markdown())
# Out:
# |       Code |   Amount Raw |   Amount Processed | Order ID           | Month    |
# |------------|--------------|--------------------|--------------------|----------|
# | 5.5026e+11 |        64000 |     62720          | TRD2022122305306   | January  |
# | 5.5026e+11 |        58092 |     56930.2        | TRD2022122500888   | January  |
# | 5.5026e+11 |        43062 |     42200.8        | TRD2022122500830   | January  |
# | 5.5026e+11 |       489000 |    479220          | TRD2022122606284   | January  |
# | 5.5026e+11 |        10000 |      9800          | TRD2022122701823   | January  |
# | 5.5026e+11 |        24000 |     23520          | TRD2022122706644   | January  |
# | 5.5026e+11 |        24000 |     23520          | TRD2022122706674   | January  |
# | 5.5026e+11 |        48080 |     47118.4        | TRD2022122801939   | January  |
# | 5.5026e+11 |       149274 |    146289          | TRD2022122802089   | January  |
# ...

# %% [markdown]
# ## Check Powerpoint Example

# %%
# Check powerpoint example
doc = converter.convert(source_powerpoint).document
print(doc.export_to_markdown())
# Out:
# WARNING:docling.models.factories.base_factory:The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# <!-- image -->
#
# Sustainable Urban Mobility Trends 2025
#
# This presentation offers urban planners insights into sustainable urban mobility. We will explore key trends and strategies. Our focus areas include EV adoption, micromobility, and smart infrastructure. Our goal is to guide future urban development.
#
# <!-- image -->
#
# by Muhammad Cikal Merdeka
#
# Key Challenges in Urban Mobility
#
# Traffic Congestion
#
# US cities lose $166 billion annually. Traffic impacts productivity and quality of life.
#
# Air Pollution
#
# Transportation causes 27% of US GHG emissions. This harms public health.
#
# Limited Accessibility
#
# Marginalized communities often lack transit options. This creates social inequity.
#
# Aging Infrastructure
#
# ...

# %% [markdown]
# ## Saving Files

# %%
# Save the document to a file (available in colab folder)
with open("pdf_with_tables_example.md", "w") as f:
    f.write(doc.export_to_markdown())

# Download to local machine (directly download from colab)
from google.colab import files
files.download("pdf_with_tables_example.md")

## Or can use the docling save method directly
doc.save_as_markdown("pdf_with_tables_example.md")
